# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavankumar2124/Class/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
# plt.plot(3,3)

# %%
plt.plot();

# %%
plt.show()

# %%
plt.plot([1,2,3,4,5]);

# %%
plt.show()

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
plt.plot(x,y)

# %%
plt.show()

# %% [markdown]
# ## the above plotting is called as the stateless plotting

# %%
plt.show()

# %% [markdown]
# ### pyplot api is less flexible than object-oriented api

# %%
#try to use the objectoriented interface than pyplot interface

# %%
fig=plt.figure()

# %%
ax=fig.add_subplot()

# %%
plt.show()

# %%
#second method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])

# %%
ax.plot(x,y)
plt.show()

# %%
## 3rd method(recommended)

# %%
fig,ax=plt.subplots()
ax.plot(x,y);

# %%
plt.show()

# %%
sfig,sax=plt.subplots()

# %%
sax.plot(x,[50,100,200,400])

# %%
plt.show()

# %% [markdown]
# ## use always method 3 for the plotting

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# the both outputs above will represent the object oriented display

# %% [markdown]
# # matplotlob example workflow

# %% [markdown]
# # 0. preparing the import if the matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.prepare data

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %% [markdown]
# # 2.setupplot

# %%
fig,ax=plt.subplots(figsize=(5,10))

# %%
# here figsize is the width and height respectively of the plot

# %% [markdown]
# # 3. plot the data

# %%
ax.plot(x,y)

# %% [markdown]
# # 4. customize the plot

# %%
ax.set(title='sample plot',xlabel='x-axis',ylabel='y-axis')
# Out:
# [Text(0.5, 1.0, 'sample plot'),
#  Text(0.5, 4.4444444444444375, 'x-axis'),
#  Text(4.4444444444444375, 0.5, 'y-axis')]

# %%
plt.show()

# %%
#fig.savefig("/Users/chowdaryadithyasaividivada/desktop/sample.png")

# %%
import numpy as np

# %%
s1=np.random.rand(100)

# %%
s1
# Out:
# array([0.89600465, 0.25711877, 0.17350374, 0.43960676, 0.66554861,
#        0.14391313, 0.43603867, 0.67355465, 0.4207558 , 0.93462737,
#        0.3245633 , 0.77208059, 0.82044419, 0.01750581, 0.64140237,
#        0.82823059, 0.94717901, 0.96234495, 0.40093237, 0.80194151,
#        0.64621334, 0.24657141, 0.06699997, 0.13800822, 0.97203049,
#        0.32962976, 0.64255146, 0.02726331, 0.01344105, 0.4847144 ,
#        0.69097994, 0.05855072, 0.51276864, 0.79103354, 0.28825644,
#        0.76762556, 0.94535275, 0.85771401, 0.17405241, 0.54159268,
#        0.84656344, 0.63303348, 0.98017313, 0.87420508, 0.26577867,
#        0.61034008, 0.20550214, 0.65813969, 0.34115711, 0.69173422,
#        0.13097687, 0.97318224, 0.05311444, 0.13649252, 0.09672182,
#        0.34926143, 0.10514364, 0.37295274, 0.80388144, 0.95924773,
#        0.97194518, 0.55333782, 0.713686  , 0.64619551, 0.63062503,
#        0.26085147, 0.41608766, 0.34964627, 0.93617284, 0.08443291,
#        0.79614087, 0.33927757, 0.09254438, 0.38098778, 0.07720905,
#        0.98978196, 0.65366438, 0.38987595, 0.17565922, 0.86817289,
#        0.10941532, 0.30911819, 0.36022792, 0.98068478, 0.44229644,
#        0.97879472, 0.24908066, 0.87910532, 0.95131738, 0.28591502,
#        0.19832485, 0.23219428, 0.95950158, 0.47771048, 0.89677771,
#        0.29117998, 0.20424782, 0.8476254 , 0.61235647, 0.69652935])

# %%
s1.ndim
# Out:
# 1

# %%
s2=np.random.rand(100,200)

# %%
s2
# Out:
# array([[0.03836214, 0.42469057, 0.36618481, ..., 0.40637279, 0.14587771,
#         0.95095969],
#        [0.99388417, 0.41504076, 0.68801785, ..., 0.61022066, 0.05649786,
#         0.25711261],
#        [0.38280699, 0.64066183, 0.67609434, ..., 0.40304655, 0.71687343,
#         0.7298837 ],
#        ...,
#        [0.03199669, 0.10132374, 0.86433935, ..., 0.74108485, 0.08914882,
#         0.47796711],
#        [0.46302502, 0.86671554, 0.4594116 , ..., 0.23962276, 0.0652004 ,
#         0.49287791],
#        [0.71098934, 0.79495674, 0.71210815, ..., 0.9392232 , 0.7401252 ,
#         0.81506727]])

# %%
s2.ndim
# Out:
# 2

# %%
s3=np.random.randint(100,200,size=(5,5))

# %%
s3
# Out:
# array([[186, 113, 166, 159, 167],
#        [166, 107, 131, 116, 135],
#        [122, 194, 157, 155, 191],
#        [135, 198, 156, 114, 190],
#        [171, 198, 172, 116, 190]])

# %%
sample=np.random.rand(100)

# %%
sinn=np.sin(sample)

# %%
sinn
# Out:
# array([0.73452323, 0.56227543, 0.18706314, 0.62813848, 0.01104525,
#        0.81280629, 0.10836494, 0.1410297 , 0.27502636, 0.53971097,
#        0.66602895, 0.83560644, 0.01179231, 0.14431619, 0.8365725 ,
#        0.36848636, 0.62436792, 0.62727106, 0.24575098, 0.60988321,
#        0.12132681, 0.21579149, 0.23636054, 0.06922741, 0.66615924,
#        0.39170708, 0.35842843, 0.17400735, 0.81452468, 0.33650546,
#        0.44484061, 0.74133279, 0.8385296 , 0.63033457, 0.12964547,
#        0.46789459, 0.01181725, 0.51607238, 0.49272898, 0.65087841,
#        0.83306229, 0.40547629, 0.59095681, 0.56650709, 0.27104332,
#        0.00816769, 0.12030692, 0.28317959, 0.62927812, 0.40668832,
#        0.59554782, 0.50099885, 0.44706582, 0.64343838, 0.30143807,
#        0.5161191 , 0.6202004 , 0.54938159, 0.70019268, 0.04737858,
#        0.22640405, 0.77891836, 0.81083754, 0.72798189, 0.32647852,
#        0.33258411, 0.09991602, 0.12577417, 0.51237504, 0.07269054,
#        0.37686042, 0.47217425, 0.249149  , 0.79564621, 0.5446592 ,
#        0.56270048, 0.03975253, 0.30281782, 0.27824588, 0.69703204,
#        0.56529141, 0.16135895, 0.72875606, 0.04753365, 0.41134713,
#        0.43520806, 0.38466265, 0.58630165, 0.65474879, 0.7731218 ,
#        0.16858561, 0.43528836, 0.79636351, 0.45143985, 0.07808049,
#        0.03985376, 0.33116583, 0.64870491, 0.80150708, 0.82480304])

# %%
fig,ax=plt.subplots(figsize=(5,5))

# %%
ax.plot(sample,sinn)

# %%
plt.show()

# %%
fig2,ax2=plt.subplots()
x=np.random.randint(100,200,size=(250))

# %%
x
# Out:
# array([144, 181, 186, 164, 181, 108, 149, 129, 176, 119, 160, 148, 104,
#        133, 111, 155, 148, 179, 145, 125, 189, 175, 113, 125, 118, 186,
#        197, 118, 188, 167, 191, 173, 178, 153, 185, 123, 171, 167, 178,
#        126, 190, 102, 170, 106, 192, 188, 169, 156, 111, 141, 152, 139,
#        137, 198, 142, 193, 194, 155, 199, 175, 144, 170, 112, 152, 126,
#        139, 101, 145, 199, 167, 109, 114, 173, 135, 174, 171, 190, 144,
#        162, 144, 124, 133, 167, 157, 170, 199, 104, 106, 100, 190, 182,
#        181, 133, 118, 152, 138, 178, 193, 110, 166, 172, 192, 149, 185,
#        123, 187, 137, 154, 124, 129, 153, 161, 110, 195, 133, 197, 145,
#        188, 122, 130, 156, 151, 158, 183, 111, 111, 107, 154, 160, 198,
#        195, 176, 112, 165, 108, 132, 135, 183, 105, 137, 163, 137, 169,
#        161, 176, 158, 140, 190, 132, 109, 171, 123, 154, 115, 179, 158,
#        151, 146, 194, 101, 132, 150, 107, 176, 172, 148, 135, 192, 141,
#        197, 111, 101, 113, 161, 182, 199, 194, 117, 108, 141, 111, 148,
#        191, 113, 102, 169, 115, 187, 160, 187, 180, 138, 162, 148, 112,
#        191, 144, 139, 187, 100, 180, 100, 182, 196, 171, 136, 178, 185,
#        100, 162, 194, 182, 123, 116, 169, 187, 192, 165, 112, 116, 180,
#        144, 182, 153, 136, 198, 108, 198, 136, 174, 174, 165, 141, 161,
#        159, 137, 144, 105, 163, 190, 144, 142, 143, 154, 181, 108, 150,
#        160, 195, 157])

# %%
ax2.plot(x)

# %%
plt.show()

# %%
#fig.savefig("/Users/chowdaryadithyasaividivada/desktop/second.png")

# %% [markdown]
# ## most common plots in machine learnign are
# #### 1.line,2.scatter,3.bar,4.hist,5.subplots()

# %%
x=np.linspace(0,10,100)
# linspace method used to create the random numbers between two numbers

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
fig,ax=plt.subplots()

# %%
ax.plot(x,x**2)

# %%
plt.show()

# %% [markdown]
# # 2. scatter plotting

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,x**2)

# %%
plt.show()

# %%
y=np.exp(x)
y
# Out:
# array([1.00000000e+00, 1.10628782e+00, 1.22387273e+00, 1.35395549e+00,
#        1.49786447e+00, 1.65706921e+00, 1.83319548e+00, 2.02804182e+00,
#        2.24359796e+00, 2.48206508e+00, 2.74587836e+00, 3.03773178e+00,
#        3.36060565e+00, 3.71779709e+00, 4.11295363e+00, 4.55011049e+00,
#        5.03373179e+00, 5.56875615e+00, 6.16064708e+00, 6.81544881e+00,
#        7.53984798e+00, 8.34124196e+00, 9.22781435e+00, 1.02086186e+01,
#        1.12936704e+01, 1.24940499e+01, 1.38220152e+01, 1.52911270e+01,
#        1.69163875e+01, 1.87143934e+01, 2.07035054e+01, 2.29040358e+01,
#        2.53384558e+01, 2.80316249e+01, 3.10110451e+01, 3.43071414e+01,
#        3.79535725e+01, 4.19875748e+01, 4.64503425e+01, 5.13874480e+01,
#        5.68493076e+01, 6.28916963e+01, 6.95763174e+01, 7.69714323e+01,
#        8.51525577e+01, 9.42032371e+01, 1.04215893e+02, 1.15292773e+02,
#        1.27546990e+02, 1.41103681e+02, 1.56101284e+02, 1.72692948e+02,
#        1.91048105e+02, 2.11354190e+02, 2.33818566e+02, 2.58670631e+02,
#        2.86164167e+02, 3.16579931e+02, 3.50228521e+02, 3.87453546e+02,
#        4.28635137e+02, 4.74193830e+02, 5.24594856e+02, 5.80352898e+02,
#        6.42037340e+02, 7.10278087e+02, 7.85771994e+02, 8.69289984e+02,
#        9.61684918e+02, 1.06390031e+03, 1.17697995e+03, 1.30207858e+03,
#        1.44047367e+03, 1.59357847e+03, 1.76295644e+03, 1.95033723e+03,
#        2.15763432e+03, 2.38696456e+03, 2.64066981e+03, 2.92134083e+03,
#        3.23184377e+03, 3.57534939e+03, 3.95536547e+03, 4.37577263e+03,
#        4.84086395e+03, 5.35538880e+03, 5.92460138e+03, 6.55431433e+03,
#        7.25095809e+03, 8.02164659e+03, 8.87424989e+03, 9.81747453e+03,
#        1.08609525e+04, 1.20153394e+04, 1.32924236e+04, 1.47052462e+04,
#        1.62682347e+04, 1.79973499e+04, 1.99102489e+04, 2.20264658e+04])

# %%
fig,ax=plt.subplots()
ax.scatter(x,y)

# %%
plt.show()

# %%
# sin function

# %%
fig,ax=plt.subplots()

# %%
ax.scatter(x,np.sin(x))

# %%
plt.show()

# %%
ax.scatter(x,np.cos(x))

# %%
plt.show()

# %% [markdown]
# ## Bar plot

# %%
fig,ax=plt.subplots()

# %%
butter={'almond':10,'peanut':8,'cashew':12}

# %%
butter
# Out:
# {'almond': 10, 'peanut': 8, 'cashew': 12}

# %%
butter.values()
# Out:
# dict_values([10, 8, 12])

# %%
butter.keys()
# Out:
# dict_keys(['almond', 'peanut', 'cashew'])

# %%
ax.bar(butter.keys(),butter.values())
ax.set(title='adithya\'s Butter store',xlabel='type of butter',ylabel='quantity')
# Out:
# [Text(0.5, 1.0, "adithya's Butter store"),
#  Text(0.5, 4.444444444444445, 'type of butter'),
#  Text(4.444444444444445, 0.5, 'quantity')]

# %%
plt.show()

# %% [markdown]
# To Make the bargraph horizontal

# %%
fig,ax=plt.subplots()

# %%
ax.barh(butter.keys(),butter.values())
ax.set(title='adityas butter house',xlabel='quantity',ylabel='types of butter')
# Out:
# [Text(0.5, 1.0, 'adityas butter house'),
#  Text(0.5, 4.444444444444445, 'quantity'),
#  Text(4.444444444444445, 0.5, 'types of butter')]

# %%
ax.barh(butter.keys(),butter.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Histogram

# %%
fig,ax=plt.subplots()

# %%
# data from a normal distribution

# %%
x=np.random.randn(100)

# %%
x
# Out:
# array([ 0.18967978, -0.47203562,  0.47604314,  1.28072317,  1.42592431,
#        -0.07531672,  1.76485586,  0.62938765,  1.24907846, -0.41276548,
#        -0.80965587,  0.09012171, -0.76528414, -1.31785056, -0.89814526,
#         1.87455467,  0.45555359, -0.21390539, -0.18461612, -0.5454133 ,
#         0.43258607,  1.47433629,  1.4179858 , -0.79868146, -0.18588921,
#        -0.65511815,  0.38344754,  0.61489179,  1.65525405,  0.67819648,
#        -1.05255059,  1.46356661, -0.28624727,  0.44361807, -0.34724577,
#        -0.04417469, -0.32794105, -0.73393067, -0.77897895,  1.23142538,
#         0.16938472, -0.33596708, -0.43154722,  1.04585052, -0.04076535,
#         1.3116111 ,  0.27321529,  0.87983306,  0.23536767, -2.19379829,
#         0.80635938,  1.38663442,  2.31456457,  1.04754562, -0.0958704 ,
#        -0.38438764,  0.02699618, -1.00825955, -0.20436674,  1.18685425,
#        -0.07797316,  0.17080563, -0.30909833,  1.20221833, -2.01429111,
#         0.81783539, -1.1298123 , -1.36954713, -1.09458023, -0.42075035,
#        -0.33690353, -0.89350523, -0.7197542 , -0.04062812,  0.93700951,
#         0.52720553,  0.28061048,  0.38332155,  0.86494107, -0.68829293,
#        -0.76420449,  0.58704779,  0.58130099,  0.62259301, -0.42720904,
#        -0.27925178, -1.21032955, -0.35610019,  0.63020053, -0.35626054,
#         1.077514  ,  0.31892416,  1.09694158,  1.95849579,  1.39788013,
#         0.22905321,  1.19782839,  0.2306186 , -0.89040689,  0.03651404])

# %%
x.ndim
# Out:
# 1

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x.shape
# Out:
# (100,)

# %%
ax.hist(x);

# %%
plt.show()
